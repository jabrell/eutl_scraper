# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from eutl_scraper.linking import map_registryCode_inv, download_file
import re

# %%
dir_in = "./data/parsed/"
tries=3 
wait=5

# %%
def link_accounts(dir_in, tries=3, wait=5):
    """Linking of account identifiers used in the transaction data and
       those used in the account database
    :param dir_in: <string> path to input data directory with data scraped
    :param trie: <int> number of retries for downloads
    :param wait: <int> number of seconds to wait between retires"""
    # get transaction block data
    df = pd.read_csv(dir_in + "transactionBlocks.csv", low_memory=False)
    
    # impose country codes and account identifiers
    def form_accountIdentifier(x, prefix):
        try:
            return f'{x[prefix + "RegistryCode"]}_{int(x[prefix + "AccountIdentifier"])}'
        except:
            return 
    for pf in ["acquiring", "transferring"]:
        df[pf + "RegistryCode"] = df[pf + "Registry"].map(lambda x: map_registryCode_inv.get(x))
        df[pf + "AccountIdentifierDB"] = df.apply(lambda x: form_accountIdentifier(x, pf), axis=1)
        
    # get a list of unique account identifies in the transaction database
    acc_id_db = list(set(list(df.transferringAccountIdentifierDB.unique()) +
                             list(df.acquiringAccountIdentifierDB.unique())))
    acc_id_db = [a for a in acc_id_db if pd.notnull(a)]  
    
    # loop over all account identifiers in the transaction database and get the accountID
    def get_linked_accountID(content):
        """ Establish mapping from accountIdentifier to accountID
        :param content: <string> content of downloaded account page
        """
        if content is None:
            return
        expr = b'<input type="hidden" name="accountID" value="\d*">'
        found = re.findall(expr, content)
        if len(found) > 0:
            found2 = re.findall(b"\d+", found[0])
            if len(found2) > 0:
                return int(found2[0])
        return

    # basic settings for donwload
    base_url = "https://ec.europa.eu/environment/ets/singleAccount.do?"
    base_qry = {"accountID": "",
                "action": "transaction",
                "registryCode": None,
                "accountIdentifier": None}

    # function to catch commissions errors string 
    def is_success(x):
            return b"An error occurred during execution of the request. Please try again later or redefine the request." not in x

    # loop over all accountIdentifier and extract associated accountID
    res = {}
    for i, accIdentifierDB in enumerate(acc_id_db):  
        if i % 100 == 0:
            print("Link accountIdentifier %s (%d/%d)" % (accIdentifierDB, i, len(acc_id_db)))
        # prepare query getting data from accountIdentifier
        query = dict(base_qry)
        query["registryCode"] = accIdentifierDB.split("_")[0]
        query["accountIdentifier"] = str(accIdentifierDB.split("_")[-1])    
         # download page
        content = download_file(base_url, parms=query, tries=tries, wait=wait, test_success=is_success)    

        accountID = get_linked_accountID(content)
        if accountID is not None:
            res[accIdentifierDB] = accountID
        else: 
            print("\tFailed to link transaction account: %s" % accIdentifierDB)

    # for security save the account mapping
    df_map = pd.DataFrame([[k,v] for k, v in res.items()], columns=["accountIdentifierDB", "accountID"])   
    df_map.to_csv(dir_in + "account_mapping.csv", index=False)
    
    # map account identified into transaction data
    for pf in ["acquiring", "transferring"]:
        df[pf + "AccountID"] = df[pf + "AccountIdentifierDB"].map(lambda x: res.get(x))
        
    # save transaction data
    df.to_csv(dir_in + "transactionBlocks.csv", index=False) 
    return

# %%
# get transaction block data
df = pd.read_csv(dir_in + "transactionBlocks.csv", low_memory=False)

# %%
# impose country codes and account identifiers
def form_accountIdentifier(x, prefix):
    try:
        return f'{x[prefix + "RegistryCode"]}_{int(x[prefix + "AccountIdentifier"])}'
    except:
        return 
    
for pf in ["acquiring", "transferring"]:
    df[pf + "RegistryCode"] = df[pf + "Registry"].map(lambda x: map_registryCode_inv.get(x))
    df[pf + "AccountIdentifierDB"] = df.apply(lambda x: form_accountIdentifier(x, pf), axis=1)
df.info(null_counts=1000000)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2079753 entries, 0 to 2079752
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   acquiringAccountIdentifier       2079663 non-null  float64
#  1   acquiringAccountName             2064667 non-null  object
#  2   acquiringAccountURL              2079604 non-null  object
#  3   acquiringRegistry                2079753 non-null  object
#  4   amount                           2079753 non-null  int64
#  5   expiryDate                       167 non-null      object
#  6   lulucfActivity                   357 non-null      float64
#  7   originalCommitmentPeriod         2079753 non-null  int64
#  8   originatingRegistry              2079753 non-null  object
#  9   projectID                        394960 non-null   float64
#  10  projectTrack                     60349 non-null    float64
#  11  transactionBlock                 2079753 non-null  int64
#  12  transactionDate                  2079753 non-null  object
#  13  transactionID                    2079753 non-null  object
#  14  transactionType                  2079753 non-null  object
#  15  transactionURL                   0 non-null        float64
#  16  transferringAccountIdentifier    2079515 non-null  float64
#  17  transferringAccountName          2040572 non-null  object
#  18  transferringAccountURL           2079584 non-null  object
#  19  transferringRegistry             2079753 non-null  object
#  20  unitType                         2079557 non-null  object
#  21  acquiringRegistryCode            2079753 non-null  object
#  22  transferringRegistryCode         2079753 non-null  object
#  23  acquiringAccountIdentifierDB     2079663 non-null  object
#  24  transferringAccountIdentifierDB  2079515 non-null  object
# dtypes: float64(6), int64(3), object(16)
# memory usage: 396.7+ MB

# %%
# get a list of unique account identifies in the transaction database
acc_id_db = list(set(list(df.transferringAccountIdentifierDB.unique()) +
                         list(df.acquiringAccountIdentifierDB.unique())))
acc_id_db = [a for a in acc_id_db if pd.notnull(a)]

# %%
# loop over all account identifiers in the transaction database and get the accountID
def get_linked_accountID(content):
    """ Establish mapping from accountIdentifier to accountID
    :param content: <string> content of downloaded account page
    """
    if content is None:
        return
    expr = b'<input type="hidden" name="accountID" value="\d*">'
    found = re.findall(expr, content)
    if len(found) > 0:
        found2 = re.findall(b"\d+", found[0])
        if len(found2) > 0:
            return int(found2[0])
    return

# basic settings for donwload
base_url = "https://ec.europa.eu/environment/ets/singleAccount.do?"
base_qry = {"accountID": "",
            "action": "transaction",
            "registryCode": None,
            "accountIdentifier": None}

# function to catch commissions errors string 
def is_success(x):
        return b"An error occurred during execution of the request. Please try again later or redefine the request." not in x
    
# loop over all accountIdentifier and extract associated accountID
res = {}
for i, accIdentifierDB in enumerate(acc_id_db):  
    if i % 100 == 0:
        print("Link accountIdentifier %s (%d/%d)" % (accIdentifierDB, i, len(acc_id_db)))
    # prepare query getting data from accountIdentifier
    query = dict(base_qry)
    query["registryCode"] = accIdentifierDB.split("_")[0]
    query["accountIdentifier"] = str(accIdentifierDB.split("_")[-1])    
     # download page
    content = download_file(base_url, parms=query, tries=tries, wait=wait, test_success=is_success)    
    
    accountID = get_linked_accountID(content)
    if accountID is not None:
        res[accIdentifierDB] = accountID
    else: 
        print("\tFailed to link transaction account: %s" % accIdentifierDB)

# for security save the account mapping
df_map = pd.DataFrame([[k,v] for k, v in res.items()], columns=["accountIdentifierDB", "accountID"])

# insert accountID into transaction data
for pf in ["acquiring", "transferring"]:
    df[pf + "AccountID"] = df[pf + "AccountIdentifierDB"].map(lambda x: res.get(x))
# Out:
# Link accountIdentifier NL_5011583 (0/34210)
# 	Failed to link transaction account: CDM_2163
# 	Failed to link transaction account: CH_1074
# Link accountIdentifier SE_680 (100/34210)
# 	Failed to link transaction account: CH_419
# 	Failed to link transaction account: CH_498
# Link accountIdentifier DE_5000699 (200/34210)
# 	Failed to link transaction account: CH_1034
# Link accountIdentifier CZ_480 (300/34210)
# 	Failed to link transaction account: AU_2617
# 	Failed to link transaction account: CY0_15
# 	Failed to link transaction account: CH_54
# 	Failed to link transaction account: CDM_2166
# 	Failed to link transaction account: JP_47
# 	Failed to link transaction account: CH_59
# 	Failed to link transaction account: CDM_2011
# 	Failed to link transaction account: NZ_10149
# Link accountIdentifier ES_714 (400/34210)
# 	Failed to link transaction account: CH_545
# 	Failed to link transaction account: UA_1
# Link accountIdentifier GB_5008107 (500/34210)
# 	Failed to link transaction account: RU_115
# 	Failed to link transaction account: JP_12
# Link accountIdentifier NL_5022515 (600/34210)
# 	Failed to link transaction account: GB_5000703
# 	Failed to link transaction account: CH_82
# Link accountIdentifier FR_5005224 (700/34210)
# 	Failed to link transaction account: GB_5017604
# 	Failed to link transaction account: CH_405
# Link accountIdentifier FR_5021444 (800/34210)
# 	Failed to link transaction account: CH_392
# 	Failed to link transaction account: GB_5016740
# 	Failed to link transaction account: CDM_2168
# 	Failed to link transaction account: GB_5000154
# Link accountIdentifier DE_5013875 (900/34210)
# 	Failed to link transaction account: CH_391
# Link accountIdentifier FR_5018923 (1000/34210)
# Link accountIdentifier DE_5014580 (1100/34210)
# 	Failed to link transaction account: CH_382
# 	Failed to link transaction account: NZ_1020
# Link accountIdentifier GB_2569 (1200/34210)
# 	Failed to link transaction account: CDM_2109
# Link accountIdentifier ES_591 (1300/34210)
# Link accountIdentifier PL_5002550 (1400/34210)
# 	Failed to link transaction account: CH_903
# 	Failed to link transaction account: GB_5019458
# Link accountIdentifier PT_5004020 (1500/34210)
# 	Failed to link transaction account: NZ_3102
# 	Failed to link transaction account: JP_100
# 	Failed to link transaction account: CH_951
# Link accountIdentifier IT_2761 (1600/34210)
# 	Failed to link transaction account: CH_693
# Link accountIdentifier FR_5005932 (1700/34210)
# 	Failed to link transaction account: CH_1076
# 	Failed to link transaction account: GB_5019280
# 	Failed to link transaction account: CDM_2131
# Link accountIdentifier PL_1042 (1800/34210)
# 	Failed to link transaction account: JP_53
# 	Failed to link transaction account: NZ_4829
# 	Failed to link transaction account: CDM_2024
# Link accountIdentifier PL_482 (1900/34210)
# 	Failed to link transaction account: CDM_2057
# 	Failed to link transaction account: JP_61
# Link accountIdentifier FR_943 (2000/34210)
# 	Failed to link transaction account: CH_502
# Link accountIdentifier BE_28 (2100/34210)
# 	Failed to link transaction account: CH_786
# 	Failed to link transaction account: GB_5020032
# Link accountIdentifier DE_1840 (2200/34210)
# 	Failed to link transaction account: GB_5000142
# 	Failed to link transaction account: CH_691
# 	Failed to link transaction account: RU_36
# 	Failed to link transaction account: CH_47
# Link accountIdentifier FI_172 (2300/34210)
# 	Failed to link transaction account: JP_203
# 	Failed to link transaction account: GB_5001062
# Link accountIdentifier SE_5001566 (2400/34210)
# 	Failed to link transaction account: CH_390
# 	Failed to link transaction account: CH_244
# Link accountIdentifier DE_5015324 (2500/34210)
# 	Failed to link transaction account: CDM_2218
# 	Failed to link transaction account: NZ_1910
# 	Failed to link transaction account: CDM_2233
# Link accountIdentifier DE_2372 (2600/34210)
# 	Failed to link transaction account: CDM_2427
# 	Failed to link transaction account: CH_856
# 	Failed to link transaction account: JP_48
# 	Failed to link transaction account: JP_82
# 	Failed to link transaction account: CH_139
# Link accountIdentifier DE_5016814 (2700/34210)
# 	Failed to link transaction account: CH_686
# 	Failed to link transaction account: CH_112
# 	Failed to link transaction account: GB_5019349
# 	Failed to link transaction account: CH_118
# Link accountIdentifier FI_5010896 (2800/34210)
# 	Failed to link transaction account: CDM_2796
# 	Failed to link transaction account: CH_96
# 	Failed to link transaction account: CH_922
# Link accountIdentifier IT_5013084 (2900/34210)
# 	Failed to link transaction account: AU_2155
# 	Failed to link transaction account: JP_27
# 	Failed to link transaction account: CDM_2162
# 	Failed to link transaction account: CH_644
# 	Failed to link transaction account: JP_445
# Link accountIdentifier DE_184 (3000/34210)
# 	Failed to link transaction account: RU_33
# Link accountIdentifier ES_1099 (3100/34210)
# Link accountIdentifier GB_6 (3200/34210)
# 	Failed to link transaction account: CH_713
# 	Failed to link transaction account: CH_1098
# Link accountIdentifier FR_173 (3300/34210)
# Link accountIdentifier HU_5011813 (3400/34210)
# 	Failed to link transaction account: CH_89
# 	Failed to link transaction account: CH_771
# Link accountIdentifier FR_5005965 (3500/34210)
# 	Failed to link transaction account: CH_1112
# 	Failed to link transaction account: CH_397
# 	Failed to link transaction account: CDM_2148
# Link accountIdentifier DK_7782 (3600/34210)
# 	Failed to link transaction account: CH_546
# 	Failed to link transaction account: CDM_2037
# Link accountIdentifier NL_5011317 (3700/34210)
# 	Failed to link transaction account: JP_204
# 	Failed to link transaction account: NZ_1981
# 	Failed to link transaction account: JP_366
# Link accountIdentifier PL_5024426 (3800/34210)
# 	Failed to link transaction account: RU_98
# Link accountIdentifier BG_7 (3900/34210)
# 	Failed to link transaction account: CH_407
# 	Failed to link transaction account: JP_430
# 	Failed to link transaction account: CH_582
# 	Failed to link transaction account: CH_2050
# Link accountIdentifier DE_1492 (4000/34210)
# 	Failed to link transaction account: RU_97
# Link accountIdentifier SE_962 (4100/34210)
# 	Failed to link transaction account: CH_505
# 	Failed to link transaction account: CH_534
# 	Failed to link transaction account: CH_495
# 	Failed to link transaction account: CH_711
# 	Failed to link transaction account: CH_491
# Link accountIdentifier IT_5013593 (4200/34210)
# 	Failed to link transaction account: CH_411
# 	Failed to link transaction account: CH_1028
# 	Failed to link transaction account: CDM_2132
# Link accountIdentifier SE_772 (4300/34210)
# 	Failed to link transaction account: CDM_2092
# 	Failed to link transaction account: NZ_1903
# 	Failed to link transaction account: CH_255
# Link accountIdentifier DE_5015823 (4400/34210)
# 	Failed to link transaction account: JP_122
# 	Failed to link transaction account: GB_5016958
# Link accountIdentifier DE_5000345 (4500/34210)
# 	Failed to link transaction account: CH_413
# 	Failed to link transaction account: JP_143
# 	Failed to link transaction account: CH_154
# 	Failed to link transaction account: GB_5000161
# Link accountIdentifier DK_136 (4600/34210)
# 	Failed to link transaction account: JP_206
# 	Failed to link transaction account: CH_128
# 	Failed to link transaction account: AU_2321
# Link accountIdentifier FR_5020677 (4700/34210)
# 	Failed to link transaction account: GB_5016561
# 	Failed to link transaction account: GB_5016741
# Link accountIdentifier PL_5003113 (4800/34210)
# 	Failed to link transaction account: JP_52
# Link accountIdentifier IT_5026177 (4900/34210)
# 	Failed to link transaction account: CDM_2033
# Link accountIdentifier IT_3116 (5000/34210)
# 	Failed to link transaction account: CH_124
# 	Failed to link transaction account: CH_53
# 	Failed to link transaction account: NZ_1235
# Link accountIdentifier IE_5000327 (5100/34210)
# 	Failed to link transaction account: CH_48
# 	Failed to link transaction account: CH_1104
# Link accountIdentifier DK_3872 (5200/34210)
# 	Failed to link transaction account: CH_485
# 	Failed to link transaction account: RU_93
# 	Failed to link transaction account: AU_1021
# Link accountIdentifier PL_601 (5300/34210)
# 	Failed to link transaction account: RU_55
# 	Failed to link transaction account: CDM_2023
# 	Failed to link transaction account: CH_813
# 	Failed to link transaction account: CH_1099
# Link accountIdentifier IT_1383 (5400/34210)
# 	Failed to link transaction account: CH_562
# 	Failed to link transaction account: CH_1094
# 	Failed to link transaction account: NZ_1194
# 	Failed to link transaction account: CH_499
# 	Failed to link transaction account: CH_904
# Link accountIdentifier DE_5014018 (5500/34210)
# 	Failed to link transaction account: JP_199
# 	Failed to link transaction account: NZ_1983
# Link accountIdentifier DK_20675 (5600/34210)
# 	Failed to link transaction account: AU_1246
# Link accountIdentifier IT_5012423 (5700/34210)
# Link accountIdentifier ES_5009391 (5800/34210)
# 	Failed to link transaction account: CH_126
# 	Failed to link transaction account: CH_625
# 	Failed to link transaction account: NZ_1065
# 	Failed to link transaction account: CH_631
# 	Failed to link transaction account: CH_480
# Link accountIdentifier ES_5008796 (5900/34210)
# 	Failed to link transaction account: CH_236
# 	Failed to link transaction account: CH_2026
# Link accountIdentifier CDM_2091 (6000/34210)
# 	Failed to link transaction account: CDM_2091
# 	Failed to link transaction account: CH_510
# Link accountIdentifier IS_5024516 (6100/34210)
# 	Failed to link transaction account: GB_5001079
# Link accountIdentifier IT_5013191 (6200/34210)
# Link accountIdentifier PL_960 (6300/34210)
# 	Failed to link transaction account: CH_638
# 	Failed to link transaction account: CDM_2032
# Link accountIdentifier IT_5012745 (6400/34210)
# 	Failed to link transaction account: AU_1141
# 	Failed to link transaction account: NZ_1162
# Link accountIdentifier DE_5015791 (6500/34210)
# Link accountIdentifier BE_139 (6600/34210)
# 	Failed to link transaction account: NZ_4409
# 	Failed to link transaction account: CDM_2085
# Link accountIdentifier FR_5024274 (6700/34210)
# 	Failed to link transaction account: GB_5016994
# 	Failed to link transaction account: CH_667
# Link accountIdentifier ES_5018278 (6800/34210)
# 	Failed to link transaction account: CH_141
# 	Failed to link transaction account: CH_987
# Link accountIdentifier IT_5018626 (6900/34210)
# 	Failed to link transaction account: RU_60
# 	Failed to link transaction account: JP_66
# 	Failed to link transaction account: NZ_10151
# 	Failed to link transaction account: JP_271
# 	Failed to link transaction account: JP_34
# Link accountIdentifier DE_5013838 (7000/34210)
# 	Failed to link transaction account: NZ_1025
# 	Failed to link transaction account: CDM_2087
# 	Failed to link transaction account: CH_963
# 	Failed to link transaction account: CH_45
# Link accountIdentifier ES_5009068 (7100/34210)
# Link accountIdentifier IT_5013614 (7200/34210)
# 	Failed to link transaction account: GB_5023348
# 	Failed to link transaction account: CH_30
# 	Failed to link transaction account: CH_2134
# 	Failed to link transaction account: JP_313
# Link accountIdentifier DE_2072 (7300/34210)
# 	Failed to link transaction account: CH_615
# Link accountIdentifier GB_625 (7400/34210)
# 	Failed to link transaction account: JP_304
# 	Failed to link transaction account: RU_39
# Link accountIdentifier DE_823 (7500/34210)
# Link accountIdentifier DK_87 (7600/34210)
# Link accountIdentifier GB_5019847 (7700/34210)
# 	Failed to link transaction account: CH_685
# 	Failed to link transaction account: CH_576
# 	Failed to link transaction account: CH_415
# Link accountIdentifier BE_76 (7800/34210)
# 	Failed to link transaction account: JP_88
# Link accountIdentifier DE_1778 (7900/34210)
# 	Failed to link transaction account: CH_532
# Link accountIdentifier IT_5013355 (8000/34210)
# 	Failed to link transaction account: CH_117
# 	Failed to link transaction account: CH_1090
# Link accountIdentifier DE_5016030 (8100/34210)
# 	Failed to link transaction account: JP_77
# 	Failed to link transaction account: CDM_2197
# Link accountIdentifier DE_1659 (8200/34210)
# 	Failed to link transaction account: CH_535
# 	Failed to link transaction account: GB_5024112
# 	Failed to link transaction account: JP_331
# 	Failed to link transaction account: AU_1024
# Link accountIdentifier DE_5014261 (8300/34210)
# 	Failed to link transaction account: CH_828
# 	Failed to link transaction account: CDM_2106
# 	Failed to link transaction account: AU_2813
# 	Failed to link transaction account: CDM_2064
# 	Failed to link transaction account: NZ_1024
# Link accountIdentifier FI_5010667 (8400/34210)
# 	Failed to link transaction account: NZ_1149
# Link accountIdentifier DE_5016001 (8500/34210)
# 	Failed to link transaction account: CDM_2052
# 	Failed to link transaction account: RU_121
# Link accountIdentifier IE_5011947 (8600/34210)
# 	Failed to link transaction account: GB_5026723
# 	Failed to link transaction account: CDM_2029
# 	Failed to link transaction account: NZ_1914
# Link accountIdentifier DE_5015546 (8700/34210)
# 	Failed to link transaction account: CH_849
# 	Failed to link transaction account: CH_500
# 	Failed to link transaction account: GB_5000060
# Link accountIdentifier GB_49 (8800/34210)
# 	Failed to link transaction account: AU_1011
# 	Failed to link transaction account: GB_5001137
# Link accountIdentifier NO_5020356 (8900/34210)
# 	Failed to link transaction account: AU_1017
# Link accountIdentifier GB_2456 (9000/34210)
# 	Failed to link transaction account: JP_103
# 	Failed to link transaction account: CH_937
# 	Failed to link transaction account: JP_22
# Link accountIdentifier RO_151 (9100/34210)
# 	Failed to link transaction account: CH_64
# 	Failed to link transaction account: JP_132
# 	Failed to link transaction account: CH_1037
# 	Failed to link transaction account: CH_113
# Link accountIdentifier DK_5976 (9200/34210)
# 	Failed to link transaction account: CH_770
# 	Failed to link transaction account: RU_107
# 	Failed to link transaction account: CDM_2116
# 	Failed to link transaction account: CH_537
# 	Failed to link transaction account: CH_56
# 	Failed to link transaction account: CH_492
# Link accountIdentifier DE_5013995 (9300/34210)
# 	Failed to link transaction account: CY0_6
# Link accountIdentifier FI_527 (9400/34210)
# 	Failed to link transaction account: MT0_3
# Link accountIdentifier AT_195 (9500/34210)
# 	Failed to link transaction account: CDM_2237
# 	Failed to link transaction account: GB_5000132
# Link accountIdentifier DK_5006456 (9600/34210)
# 	Failed to link transaction account: CH_453
# 	Failed to link transaction account: GB_5019792
# 	Failed to link transaction account: GB_5017352
# 	Failed to link transaction account: GB_5000111
# Link accountIdentifier DK_361 (9700/34210)
# 	Failed to link transaction account: NZ_8854
# Link accountIdentifier CZ_5006912 (9800/34210)
# 	Failed to link transaction account: AU_1036
# Link accountIdentifier ES_5000685 (9900/34210)
# 	Failed to link transaction account: CDM_2078
# 	Failed to link transaction account: JP_125
# Link accountIdentifier ES_5009166 (10000/34210)
# 	Failed to link transaction account: RU_54
# Link accountIdentifier NO_5019529 (10100/34210)
# 	Failed to link transaction account: GB_5000145
# Link accountIdentifier FI_179 (10200/34210)
# 	Failed to link transaction account: CH_2
# 	Failed to link transaction account: CH_504
# 	Failed to link transaction account: CDM_2089
# 	Failed to link transaction account: CH_2022
# Link accountIdentifier SE_645 (10300/34210)
# 	Failed to link transaction account: CH_1030
# Link accountIdentifier ES_5009906 (10400/34210)
# 	Failed to link transaction account: CH_1047
# Link accountIdentifier GB_5007658 (10500/34210)
# 	Failed to link transaction account: CDM_2084
# 	Failed to link transaction account: CH_2023
# 	Failed to link transaction account: CH_649
# Link accountIdentifier DE_5014503 (10600/34210)
# 	Failed to link transaction account: GB_5018993
# 	Failed to link transaction account: CH_1105
# 	Failed to link transaction account: CH_897
# 	Failed to link transaction account: CH_277
# Link accountIdentifier DE_5015528 (10700/34210)
# 	Failed to link transaction account: CDM_2044
# 	Failed to link transaction account: GB_5017263
# Link accountIdentifier IT_5012890 (10800/34210)
# 	Failed to link transaction account: CDM_2207
# 	Failed to link transaction account: CH_105
# Link accountIdentifier SI_40 (10900/34210)
# 	Failed to link transaction account: CH_22
# 	Failed to link transaction account: CH_101
# 	Failed to link transaction account: CDM_2068
# 	Failed to link transaction account: CH_58
# 	Failed to link transaction account: NZ_1060
# Link accountIdentifier CZ_242 (11000/34210)
# 	Failed to link transaction account: CDM_2231
# Link accountIdentifier PL_5003878 (11100/34210)
# 	Failed to link transaction account: GB_5016929
# 	Failed to link transaction account: RU_78
# Link accountIdentifier DE_5015491 (11200/34210)
# 	Failed to link transaction account: JP_459
# 	Failed to link transaction account: GB_5017201
# Link accountIdentifier NL_764 (11300/34210)
# 	Failed to link transaction account: GB_5016817
# Link accountIdentifier SK_5003119 (11400/34210)
# 	Failed to link transaction account: CH_2049
# 	Failed to link transaction account: NZ_1990
# Link accountIdentifier PL_5002696 (11500/34210)
# 	Failed to link transaction account: RU_68
# 	Failed to link transaction account: CDM_2099
# Link accountIdentifier FR_5005593 (11600/34210)
# 	Failed to link transaction account: RU_61
# 	Failed to link transaction account: CH_607
# 	Failed to link transaction account: CH_514
# Link accountIdentifier FR_5000424 (11700/34210)
# 	Failed to link transaction account: CH_412
# 	Failed to link transaction account: CH_733
# 	Failed to link transaction account: CH_44
# 	Failed to link transaction account: CH_449
# 	Failed to link transaction account: CH_766
# 	Failed to link transaction account: NZ_1193
# 	Failed to link transaction account: CH_476
# 	Failed to link transaction account: CH_51
# 	Failed to link transaction account: CH_757
# Link accountIdentifier NO_5012246 (11800/34210)
# 	Failed to link transaction account: CDM_2040
# 	Failed to link transaction account: MT0_5
# 	Failed to link transaction account: NZ_1150
# 	Failed to link transaction account: CH_81
# 	Failed to link transaction account: CH_838
# Link accountIdentifier DE_5013827 (11900/34210)
# 	Failed to link transaction account: CDM_2026
# 	Failed to link transaction account: CH_509
# Link accountIdentifier NL_815 (12000/34210)
# Link accountIdentifier DE_5014855 (12100/34210)
# Link accountIdentifier CDM_2115 (12200/34210)
# 	Failed to link transaction account: CDM_2115
# 	Failed to link transaction account: CDM_2204
# Link accountIdentifier GB_5007945 (12300/34210)
# 	Failed to link transaction account: NZ_1013
# Link accountIdentifier FI_5010353 (12400/34210)
# 	Failed to link transaction account: CH_629
# Link accountIdentifier RO_127 (12500/34210)
# 	Failed to link transaction account: CH_632
# 	Failed to link transaction account: CH_50
# Link accountIdentifier BE_5004365 (12600/34210)
# 	Failed to link transaction account: CH_626
# 	Failed to link transaction account: CH_1044
# Link accountIdentifier GB_5007274 (12700/34210)
# 	Failed to link transaction account: CH_700
# 	Failed to link transaction account: CDM_2135
# Link accountIdentifier GB_351 (12800/34210)
# 	Failed to link transaction account: CH_271
# 	Failed to link transaction account: CH_530
# Link accountIdentifier SE_446 (12900/34210)
# 	Failed to link transaction account: GB_5018854
# 	Failed to link transaction account: AU_1439
# 	Failed to link transaction account: CH_77
# Link accountIdentifier PL_5022286 (13000/34210)
# 	Failed to link transaction account: CH_538
# Link accountIdentifier NL_5011202 (13100/34210)
# 	Failed to link transaction account: JP_255
# 	Failed to link transaction account: CH_749
# Link accountIdentifier PL_5027442 (13200/34210)
# 	Failed to link transaction account: CH_726
# 	Failed to link transaction account: CH_839
# 	Failed to link transaction account: CY0_19
# Link accountIdentifier SE_67 (13300/34210)
# 	Failed to link transaction account: GB_5016457
# 	Failed to link transaction account: CDM_2039
# Link accountIdentifier GB_5007267 (13400/34210)
# 	Failed to link transaction account: CH_516
# 	Failed to link transaction account: CDM_2865
# Link accountIdentifier GR_5002461 (13500/34210)
# 	Failed to link transaction account: CH_414
# Link accountIdentifier DK_2070 (13600/34210)
# 	Failed to link transaction account: CH_434
# 	Failed to link transaction account: CH_1001
# Link accountIdentifier DE_5014623 (13700/34210)
# 	Failed to link transaction account: CH_529
# 	Failed to link transaction account: CDM_2108
# Link accountIdentifier FR_5005925 (13800/34210)
# 	Failed to link transaction account: GB_5017751
# 	Failed to link transaction account: CH_1039
# 	Failed to link transaction account: CH_489
# 	Failed to link transaction account: CH_888
# 	Failed to link transaction account: CH_575
# Link accountIdentifier ES_5009044 (13900/34210)
# 	Failed to link transaction account: AU_1032
# 	Failed to link transaction account: CH_573
# 	Failed to link transaction account: RU_90
# 	Failed to link transaction account: CH_788
# 	Failed to link transaction account: CDM_2094
# 	Failed to link transaction account: CH_88
# Link accountIdentifier NO_5012225 (14000/34210)
# 	Failed to link transaction account: GB_5016620
# 	Failed to link transaction account: CH_861
# 	Failed to link transaction account: CH_1036
# Link accountIdentifier ES_5009762 (14100/34210)
# 	Failed to link transaction account: CDM_2615
# 	Failed to link transaction account: RU_88
# 	Failed to link transaction account: CH_487
# Link accountIdentifier CZ_247 (14200/34210)
# 	Failed to link transaction account: CH_99
# Link accountIdentifier DK_5023801 (14300/34210)
# 	Failed to link transaction account: CH_325
# 	Failed to link transaction account: CH_120
# 	Failed to link transaction account: GB_5017094
# 	Failed to link transaction account: JP_282
# 	Failed to link transaction account: NZ_3432
# Link accountIdentifier GB_339 (14400/34210)
# 	Failed to link transaction account: CH_884
# 	Failed to link transaction account: CH_398
# Link accountIdentifier SK_171 (14500/34210)
# 	Failed to link transaction account: CH_1052
# 	Failed to link transaction account: CH_852
# 	Failed to link transaction account: NZ_2804
# Link accountIdentifier FR_95 (14600/34210)
# 	Failed to link transaction account: CH_282
# 	Failed to link transaction account: RU_46
# Link accountIdentifier ES_405 (14700/34210)
# 	Failed to link transaction account: ESD_5024965
# Link accountIdentifier ES_5009091 (14800/34210)
# 	Failed to link transaction account: RU_53
# Link accountIdentifier ES_5025056 (14900/34210)
# 	Failed to link transaction account: CH_1015
# Link accountIdentifier DE_2789 (15000/34210)
# 	Failed to link transaction account: JP_265
# 	Failed to link transaction account: CDM_2202
# 	Failed to link transaction account: NZ_1885
# 	Failed to link transaction account: GB_5000718
# Link accountIdentifier IT_2205 (15100/34210)
# 	Failed to link transaction account: NZ_9220
# 	Failed to link transaction account: CH_250
# Link accountIdentifier EE_30 (15200/34210)
# 	Failed to link transaction account: CDM_2013
# Link accountIdentifier DE_5014005 (15300/34210)
# 	Failed to link transaction account: CH_55
# 	Failed to link transaction account: CH_848
# 	Failed to link transaction account: CDM_2101
# Link accountIdentifier ES_5019430 (15400/34210)
# 	Failed to link transaction account: NZ_1720
# 	Failed to link transaction account: CDM_2065
# 	Failed to link transaction account: JP_36
# Link accountIdentifier GB_5022504 (15500/34210)
# 	Failed to link transaction account: CH_488
# Link accountIdentifier PL_134 (15600/34210)
# 	Failed to link transaction account: CH_2063
# 	Failed to link transaction account: CH_43
# 	Failed to link transaction account: CH_592
# Link accountIdentifier GB_5020342 (15700/34210)
# 	Failed to link transaction account: JP_17
# 	Failed to link transaction account: CH_78
# 	Failed to link transaction account: CH_370
# Link accountIdentifier FI_5010791 (15800/34210)
# 	Failed to link transaction account: CH_2057
# 	Failed to link transaction account: CDM_2020
# Link accountIdentifier NL_5011349 (15900/34210)
# 	Failed to link transaction account: CH_560
# 	Failed to link transaction account: GB_5000091
# 	Failed to link transaction account: CH_702
# 	Failed to link transaction account: CH_2136
# 	Failed to link transaction account: GB_5016742
# Link accountIdentifier AU_2848 (16000/34210)
# 	Failed to link transaction account: AU_2848
# 	Failed to link transaction account: RU_52
# 	Failed to link transaction account: CH_544
# 	Failed to link transaction account: CH_671
# 	Failed to link transaction account: CH_677
# Link accountIdentifier ES_5009557 (16100/34210)
# 	Failed to link transaction account: GB_5000507
# Link accountIdentifier DK_15069 (16200/34210)
# 	Failed to link transaction account: JP_58
# 	Failed to link transaction account: CH_477
# 	Failed to link transaction account: JP_68
# Link accountIdentifier FR_53 (16300/34210)
# 	Failed to link transaction account: RU_89
# 	Failed to link transaction account: CDM_2048
# 	Failed to link transaction account: CH_942
# 	Failed to link transaction account: CH_811
# Link accountIdentifier NO_5024788 (16400/34210)
# 	Failed to link transaction account: AU_2649
# 	Failed to link transaction account: CH_378
# 	Failed to link transaction account: CDM_2015
# Link accountIdentifier FR_1388 (16500/34210)
# 	Failed to link transaction account: RU_120
# 	Failed to link transaction account: CH_855
# Link accountIdentifier FR_1406 (16600/34210)
# 	Failed to link transaction account: CH_869
# Link accountIdentifier PL_5018168 (16700/34210)
# 	Failed to link transaction account: CH_2165
# 	Failed to link transaction account: CH_837
# Link accountIdentifier FR_1282 (16800/34210)
# 	Failed to link transaction account: CH_670
# 	Failed to link transaction account: CH_389
# 	Failed to link transaction account: JP_437
# Link accountIdentifier IT_1431 (16900/34210)
# 	Failed to link transaction account: NZ_10219
# 	Failed to link transaction account: GB_5024191
# Link accountIdentifier DE_5013983 (17000/34210)
# 	Failed to link transaction account: CDM_2014
# 	Failed to link transaction account: CH_253
# Link accountIdentifier NL_251 (17100/34210)
# 	Failed to link transaction account: CDM_2042
# 	Failed to link transaction account: GB_5026248
# 	Failed to link transaction account: CH_349
# Link accountIdentifier DE_1348 (17200/34210)
# 	Failed to link transaction account: CH_83
# Link accountIdentifier DK_15081 (17300/34210)
# 	Failed to link transaction account: JP_11
# 	Failed to link transaction account: CDM_2027
# Link accountIdentifier FR_988 (17400/34210)
# 	Failed to link transaction account: NZ_10270
# Link accountIdentifier DK_322 (17500/34210)
# 	Failed to link transaction account: JP_321
# Link accountIdentifier IT_2588 (17600/34210)
# 	Failed to link transaction account: CH_1053
# 	Failed to link transaction account: CH_462
# Link accountIdentifier PL_320 (17700/34210)
# 	Failed to link transaction account: CH_701
# 	Failed to link transaction account: CDM_2067
# 	Failed to link transaction account: RU_79
# 	Failed to link transaction account: CH_490
# 	Failed to link transaction account: GB_5018082
# Link accountIdentifier DE_5020161 (17800/34210)
# 	Failed to link transaction account: GB_5017514
# 	Failed to link transaction account: CH_373
# Link accountIdentifier DE_1721 (17900/34210)
# 	Failed to link transaction account: CH_142
# 	Failed to link transaction account: CH_169
# Link accountIdentifier IT_1771 (18000/34210)
# 	Failed to link transaction account: CDM_1000
# 	Failed to link transaction account: CDM_2134
# 	Failed to link transaction account: CH_145
# Link accountIdentifier PL_5003806 (18100/34210)
# 	Failed to link transaction account: CH_587
# 	Failed to link transaction account: CH_451
# 	Failed to link transaction account: CH_653
# Link accountIdentifier RO_5010132 (18200/34210)
# 	Failed to link transaction account: RU_32
# 	Failed to link transaction account: NZ_1324
# Link accountIdentifier DE_756 (18300/34210)
# 	Failed to link transaction account: JP_40
# 	Failed to link transaction account: CY0_18
# 	Failed to link transaction account: CH_503
# Link accountIdentifier ES_5008974 (18400/34210)
# 	Failed to link transaction account: NZ_1470
# Link accountIdentifier FR_5005184 (18500/34210)
# 	Failed to link transaction account: CH_574
# Link accountIdentifier GB_5007506 (18600/34210)
# 	Failed to link transaction account: CDM_2035
# 	Failed to link transaction account: RU_48
# 	Failed to link transaction account: JP_405
# Link accountIdentifier PT_5002690 (18700/34210)
# 	Failed to link transaction account: MT0_1
# 	Failed to link transaction account: CH_496
# 	Failed to link transaction account: CH_98
# Link accountIdentifier GB_2047 (18800/34210)
# 	Failed to link transaction account: CDM_2098
# 	Failed to link transaction account: CH_569
# 	Failed to link transaction account: RU_38
# 	Failed to link transaction account: CH_133
# 	Failed to link transaction account: GB_5017823
# Link accountIdentifier FI_5010609 (18900/34210)
# 	Failed to link transaction account: CDM_2006
# 	Failed to link transaction account: CDM_2028
# Link accountIdentifier IT_2200 (19000/34210)
# Link accountIdentifier DE_5017225 (19100/34210)
# 	Failed to link transaction account: CDM_2784
# Link accountIdentifier GB_5025620 (19200/34210)
# Link accountIdentifier GB_756 (19300/34210)
# 	Failed to link transaction account: NZ_1932
# Link accountIdentifier GB_5007486 (19400/34210)
# 	Failed to link transaction account: CH_116
# Link accountIdentifier HU_2535 (19500/34210)
# 	Failed to link transaction account: RU_50
# 	Failed to link transaction account: CH_91
# 	Failed to link transaction account: GB_5000737
# Link accountIdentifier IE_168 (19600/34210)
# 	Failed to link transaction account: CH_515
# 	Failed to link transaction account: CH_1106
# Link accountIdentifier GB_5008047 (19700/34210)
# 	Failed to link transaction account: CH_49
# Link accountIdentifier IT_1507 (19800/34210)
# 	Failed to link transaction account: CDM_2022
# 	Failed to link transaction account: CH_74
# 	Failed to link transaction account: JP_113
# Link accountIdentifier GB_529 (19900/34210)
# 	Failed to link transaction account: CH_556
# 	Failed to link transaction account: CDM_2046
# 	Failed to link transaction account: CH_797
# Link accountIdentifier GR_114 (20000/34210)
# Link accountIdentifier PT_5004027 (20100/34210)
# Link accountIdentifier DK_12997 (20200/34210)
# 	Failed to link transaction account: NZ_1971
# Link accountIdentifier FI_434 (20300/34210)
# Link accountIdentifier AT_228 (20400/34210)
# 	Failed to link transaction account: CY0_10
# Link accountIdentifier RO_5023636 (20500/34210)
# 	Failed to link transaction account: CH_2040
# Link accountIdentifier CH_982 (20600/34210)
# 	Failed to link transaction account: CH_982
# 	Failed to link transaction account: CH_692
# 	Failed to link transaction account: GB_5019701
# 	Failed to link transaction account: CH_823
# Link accountIdentifier NL_5011092 (20700/34210)
# 	Failed to link transaction account: CH_572
# 	Failed to link transaction account: GB_5024564
# 	Failed to link transaction account: CH_1062
# Link accountIdentifier AT_5020362 (20800/34210)
# 	Failed to link transaction account: CDM_2556
# 	Failed to link transaction account: CDM_1004
# 	Failed to link transaction account: CH_2062
# 	Failed to link transaction account: CH_1061
# 	Failed to link transaction account: CH_153
# Link accountIdentifier DE_5014162 (20900/34210)
# 	Failed to link transaction account: CH_860
# 	Failed to link transaction account: JP_29
# 	Failed to link transaction account: CH_52
# Link accountIdentifier PL_88 (21000/34210)
# 	Failed to link transaction account: CH_868
# 	Failed to link transaction account: CH_416
# Link accountIdentifier PL_847 (21100/34210)
# 	Failed to link transaction account: CY0_11
# 	Failed to link transaction account: CH_307
# 	Failed to link transaction account: CDM_2045
# 	Failed to link transaction account: CH_134
# Link accountIdentifier NO_5018840 (21200/34210)
# 	Failed to link transaction account: CH_714
# 	Failed to link transaction account: CH_565
# Link accountIdentifier DE_5026900 (21300/34210)
# 	Failed to link transaction account: NZ_1744
# Link accountIdentifier IT_5012561 (21400/34210)
# 	Failed to link transaction account: CH_2088
# 	Failed to link transaction account: NZ_1033
# Link accountIdentifier ES_5008860 (21500/34210)
# 	Failed to link transaction account: CH_471
# 	Failed to link transaction account: NZ_4970
# 	Failed to link transaction account: CDM_2199
# 	Failed to link transaction account: CH_152
# Link accountIdentifier GB_13 (21600/34210)
# 	Failed to link transaction account: JP_30
# 	Failed to link transaction account: AU_1039
# 	Failed to link transaction account: CH_72
# 	Failed to link transaction account: NZ_3568
# 	Failed to link transaction account: JP_111
# 	Failed to link transaction account: CH_673
# Link accountIdentifier PT_257 (21700/34210)
# 	Failed to link transaction account: CH_521
# 	Failed to link transaction account: CH_2182
# Link accountIdentifier SI_5008636 (21800/34210)
# 	Failed to link transaction account: GB_5018855
# 	Failed to link transaction account: CH_988
# 	Failed to link transaction account: JP_314
# 	Failed to link transaction account: CDM_2174
# Link accountIdentifier DE_5015354 (21900/34210)
# 	Failed to link transaction account: CH_966
# 	Failed to link transaction account: GB_5000316
# Link accountIdentifier FR_5023483 (22000/34210)
# 	Failed to link transaction account: JP_31
# 	Failed to link transaction account: CH_1103
# Link accountIdentifier FI_369 (22100/34210)
# 	Failed to link transaction account: CH_628
# 	Failed to link transaction account: CY0_9
# Link accountIdentifier GB_5018455 (22200/34210)
# 	Failed to link transaction account: CDM_2239
# 	Failed to link transaction account: CH_410
# 	Failed to link transaction account: CH_684
# Link accountIdentifier NL_100 (22300/34210)
# 	Failed to link transaction account: CH_540
# Link accountIdentifier DE_1628 (22400/34210)
# 	Failed to link transaction account: JP_86
# 	Failed to link transaction account: CH_467
# 	Failed to link transaction account: CH_871
# 	Failed to link transaction account: JP_57
# Link accountIdentifier RO_5010309 (22500/34210)
# 	Failed to link transaction account: CH_1048
# 	Failed to link transaction account: CH_541
# 	Failed to link transaction account: CH_1038
# Link accountIdentifier SK_77 (22600/34210)
# 	Failed to link transaction account: CH_404
# Link accountIdentifier PL_5002583 (22700/34210)
# 	Failed to link transaction account: NZ_1808
# 	Failed to link transaction account: CH_1027
# Link accountIdentifier DK_8272 (22800/34210)
# 	Failed to link transaction account: RU_108
# Link accountIdentifier IT_5013208 (22900/34210)
# Link accountIdentifier FR_5005233 (23000/34210)
# 	Failed to link transaction account: CDM_2038
# 	Failed to link transaction account: JP_419
# 	Failed to link transaction account: NZ_2567
# Link accountIdentifier ES_5021481 (23100/34210)
# 	Failed to link transaction account: JP_87
# 	Failed to link transaction account: CDM_2060
# Link accountIdentifier HU_216 (23200/34210)
# 	Failed to link transaction account: CH_652
# 	Failed to link transaction account: CDM_2146
# Link accountIdentifier SE_91 (23300/34210)
# 	Failed to link transaction account: CH_140
# Link accountIdentifier BG_62 (23400/34210)
# Link accountIdentifier PT_5808 (23500/34210)
# 	Failed to link transaction account: NZ_9072
# 	Failed to link transaction account: CH_584
# 	Failed to link transaction account: CH_948
# 	Failed to link transaction account: CY0_17
# 	Failed to link transaction account: CH_680
# 	Failed to link transaction account: CH_956
# Link accountIdentifier DE_5017900 (23600/34210)
# 	Failed to link transaction account: GB_5020025
# 	Failed to link transaction account: CDM_2012
# 	Failed to link transaction account: CDM_2171
# 	Failed to link transaction account: GB_5000977
# 	Failed to link transaction account: CDM_2200
# 	Failed to link transaction account: CH_672
# 	Failed to link transaction account: CH_1017
# Link accountIdentifier CH_497 (23700/34210)
# 	Failed to link transaction account: CH_497
# 	Failed to link transaction account: CH_874
# 	Failed to link transaction account: RU_47
# 	Failed to link transaction account: RU_37
# Link accountIdentifier GB_5017319 (23800/34210)
# 	Failed to link transaction account: GB_5016666
# 	Failed to link transaction account: CH_71
# Link accountIdentifier CZ_5007032 (23900/34210)
# 	Failed to link transaction account: JP_33
# 	Failed to link transaction account: CDM_2051
# Link accountIdentifier DE_349 (24000/34210)
# 	Failed to link transaction account: CH_508
# 	Failed to link transaction account: JP_495
# 	Failed to link transaction account: NZ_6303
# 	Failed to link transaction account: CH_859
# Link accountIdentifier DE_5014190 (24100/34210)
# 	Failed to link transaction account: CH_80
# 	Failed to link transaction account: JP_461
# Link accountIdentifier DK_10787 (24200/34210)
# 	Failed to link transaction account: CH_784
# Link accountIdentifier DE_5020702 (24300/34210)
# 	Failed to link transaction account: GB_5000521
# 	Failed to link transaction account: CH_679
# 	Failed to link transaction account: CDM_2187
# 	Failed to link transaction account: CH_138
# 	Failed to link transaction account: CH_933
# 	Failed to link transaction account: CH_542
# 	Failed to link transaction account: CDM_2130
# Link accountIdentifier DE_5015283 (24400/34210)
# 	Failed to link transaction account: CH_447
# 	Failed to link transaction account: CH_2158
# 	Failed to link transaction account: CH_1113
# Link accountIdentifier NL_5011445 (24500/34210)
# 	Failed to link transaction account: AU_1384
# 	Failed to link transaction account: CH_617
# Link accountIdentifier DE_5015601 (24600/34210)
# 	Failed to link transaction account: GB_5018224
# Link accountIdentifier CZ_199 (24700/34210)
# Link accountIdentifier FR_243 (24800/34210)
# 	Failed to link transaction account: AU_1012
# Link accountIdentifier GB_371 (24900/34210)
# 	Failed to link transaction account: GB_5018047
# 	Failed to link transaction account: CDM_2375
# Link accountIdentifier GB_5024397 (25000/34210)
# Link accountIdentifier DE_5019327 (25100/34210)
# 	Failed to link transaction account: CH_87
# 	Failed to link transaction account: NZ_1050
# Link accountIdentifier SK_5004023 (25200/34210)
# 	Failed to link transaction account: JP_79
# 	Failed to link transaction account: GB_5000777
# 	Failed to link transaction account: CH_634
# Link accountIdentifier PL_350 (25300/34210)
# 	Failed to link transaction account: CDM_2179
# 	Failed to link transaction account: CH_513
# Link accountIdentifier PL_941 (25400/34210)
# 	Failed to link transaction account: NZ_4830
# Link accountIdentifier GB_5021618 (25500/34210)
# 	Failed to link transaction account: JP_133
# 	Failed to link transaction account: CH_150
# Link accountIdentifier SE_5002220 (25600/34210)
# 	Failed to link transaction account: GB_5000115
# Link accountIdentifier SE_5001516 (25700/34210)
# 	Failed to link transaction account: JP_198
# 	Failed to link transaction account: CH_755
# Link accountIdentifier DK_4570 (25800/34210)
# 	Failed to link transaction account: CH_158
# Link accountIdentifier CZ_5006706 (25900/34210)
# 	Failed to link transaction account: CH_494
# 	Failed to link transaction account: JP_41
# Link accountIdentifier IE_171 (26000/34210)
# 	Failed to link transaction account: CH_114
# 	Failed to link transaction account: DE_5000738
# 	Failed to link transaction account: CH_959
# 	Failed to link transaction account: CH_882
# 	Failed to link transaction account: MT0_4
# Link accountIdentifier GB_476 (26100/34210)
# 	Failed to link transaction account: CH_862
# Link accountIdentifier DE_340 (26200/34210)
# 	Failed to link transaction account: GB_5025960
# 	Failed to link transaction account: CH_93
# Link accountIdentifier GB_1998 (26300/34210)
# Link accountIdentifier CH_853 (26400/34210)
# 	Failed to link transaction account: CH_853
# 	Failed to link transaction account: CH_973
# 	Failed to link transaction account: RU_101
# Link accountIdentifier IT_5018260 (26500/34210)
# Link accountIdentifier GR_5002290 (26600/34210)
# 	Failed to link transaction account: JP_37
# 	Failed to link transaction account: RU_109
# Link accountIdentifier IT_1390 (26700/34210)
# 	Failed to link transaction account: CH_728
# 	Failed to link transaction account: CH_614
# 	Failed to link transaction account: CH_623
# 	Failed to link transaction account: CH_60
# 	Failed to link transaction account: NZ_5177
# Link accountIdentifier DE_5015613 (26800/34210)
# 	Failed to link transaction account: CH_899
# Link accountIdentifier SK_134 (26900/34210)
# 	Failed to link transaction account: CH_938
# Link accountIdentifier LU_5020086 (27000/34210)
# 	Failed to link transaction account: CH_2030
# 	Failed to link transaction account: NZ_1671
# Link accountIdentifier FI_259 (27100/34210)
# 	Failed to link transaction account: CH_381
# Link accountIdentifier HU_306 (27200/34210)
# 	Failed to link transaction account: AU_1222
# Link accountIdentifier GB_5008348 (27300/34210)
# 	Failed to link transaction account: CH_1019
# 	Failed to link transaction account: RU_116
# 	Failed to link transaction account: AU_2845
# 	Failed to link transaction account: CH_461
# 	Failed to link transaction account: CH_507
# Link accountIdentifier BE_877 (27400/34210)
# 	Failed to link transaction account: JP_289
# Link accountIdentifier DK_9772 (27500/34210)
# 	Failed to link transaction account: CH_1107
# 	Failed to link transaction account: CH_536
# Link accountIdentifier CZ_5006619 (27600/34210)
# 	Failed to link transaction account: AU_1267
# 	Failed to link transaction account: JP_18
# Link accountIdentifier SE_5001599 (27700/34210)
# 	Failed to link transaction account: CDM_2056
# Link accountIdentifier BG_100 (27800/34210)
# 	Failed to link transaction account: CH_493
# 	Failed to link transaction account: CDM_2149
# Link accountIdentifier GB_5018138 (27900/34210)
# 	Failed to link transaction account: RU_66
# Link accountIdentifier FR_1060 (28000/34210)
# Link accountIdentifier SE_123 (28100/34210)
# 	Failed to link transaction account: GB_5016651
# 	Failed to link transaction account: CH_2045
# Link accountIdentifier IT_5013585 (28200/34210)
# 	Failed to link transaction account: CH_567
# Link accountIdentifier DE_5021136 (28300/34210)
# 	Failed to link transaction account: CH_1108
# 	Failed to link transaction account: CDM_2136
# 	Failed to link transaction account: CDM_2083
# Link accountIdentifier DK_7893 (28400/34210)
# 	Failed to link transaction account: CY0_8
# 	Failed to link transaction account: RU_41
# Link accountIdentifier IT_2249 (28500/34210)
# 	Failed to link transaction account: CDM_2008
# 	Failed to link transaction account: CH_830
# 	Failed to link transaction account: GB_5026387
# 	Failed to link transaction account: AU_1055
# 	Failed to link transaction account: CDM_2063
# Link accountIdentifier HU_5011825 (28600/34210)
# 	Failed to link transaction account: AU_1066
# 	Failed to link transaction account: CDM_2007
# 	Failed to link transaction account: RU_51
# 	Failed to link transaction account: CDM_2086
# 	Failed to link transaction account: CH_769
# Link accountIdentifier DE_1480 (28700/34210)
# 	Failed to link transaction account: NZ_1604
# 	Failed to link transaction account: AU_1324
# 	Failed to link transaction account: CDM_2409
# Link accountIdentifier PL_5003072 (28800/34210)
# 	Failed to link transaction account: CH_581
# Link accountIdentifier FI_5010814 (28900/34210)
# Link accountIdentifier ES_5009580 (29000/34210)
# 	Failed to link transaction account: GB_5016654
# 	Failed to link transaction account: CDM_2139
# 	Failed to link transaction account: CH_512
# 	Failed to link transaction account: RU_40
# Link accountIdentifier SE_5001767 (29100/34210)
# 	Failed to link transaction account: CH_196
# 	Failed to link transaction account: CH_100
# 	Failed to link transaction account: CH_2172
# Link accountIdentifier DK_5021198 (29200/34210)
# 	Failed to link transaction account: NZ_10039
# 	Failed to link transaction account: CH_525
# 	Failed to link transaction account: CDM_2104
# Link accountIdentifier SI_5008684 (29300/34210)
# 	Failed to link transaction account: CDM_2110
# Link accountIdentifier PT_233 (29400/34210)
# 	Failed to link transaction account: JP_49
# 	Failed to link transaction account: CH_792
# 	Failed to link transaction account: CH_775
# Link accountIdentifier IT_5013031 (29500/34210)
# 	Failed to link transaction account: NZ_1939
# 	Failed to link transaction account: GB_5000621
# Link accountIdentifier GB_1418 (29600/34210)
# 	Failed to link transaction account: JP_128
# 	Failed to link transaction account: GB_5027786
# Link accountIdentifier DE_5013742 (29700/34210)
# 	Failed to link transaction account: CH_206
# 	Failed to link transaction account: CH_705
# Link accountIdentifier GB_5026290 (29800/34210)
# 	Failed to link transaction account: CDM_2182
# 	Failed to link transaction account: CH_690
# 	Failed to link transaction account: CH_731
# 	Failed to link transaction account: GB_5024146
# 	Failed to link transaction account: NZ_1053
# Link accountIdentifier PL_419 (29900/34210)
# 	Failed to link transaction account: CDM_2097
# 	Failed to link transaction account: RU_69
# 	Failed to link transaction account: CH_483
# Link accountIdentifier AT_5004052 (30000/34210)
# 	Failed to link transaction account: CH_2142
# 	Failed to link transaction account: CDM_2225
# 	Failed to link transaction account: GB_5026104
# Link accountIdentifier IT_5013400 (30100/34210)
# 	Failed to link transaction account: CH_129
# 	Failed to link transaction account: JP_54
# Link accountIdentifier GB_2877 (30200/34210)
# 	Failed to link transaction account: CH_2025
# 	Failed to link transaction account: CY0_13
# 	Failed to link transaction account: CH_95
# 	Failed to link transaction account: NZ_5380
# Link accountIdentifier DE_5014847 (30300/34210)
# 	Failed to link transaction account: CH_186
# 	Failed to link transaction account: CDM_2183
# Link accountIdentifier GB_5007941 (30400/34210)
# 	Failed to link transaction account: NZ_1028
# 	Failed to link transaction account: CH_46
# Link accountIdentifier NL_5022307 (30500/34210)
# 	Failed to link transaction account: NZ_2455
# 	Failed to link transaction account: RU_118
# 	Failed to link transaction account: RU_111
# Link accountIdentifier GB_5007585 (30600/34210)
# 	Failed to link transaction account: CH_42
# 	Failed to link transaction account: CDM_2047
# 	Failed to link transaction account: CY0_14
# Link accountIdentifier IT_5013023 (30700/34210)
# 	Failed to link transaction account: CH_996
# Link accountIdentifier ES_630 (30800/34210)
# 	Failed to link transaction account: CH_450
# 	Failed to link transaction account: CH_131
# 	Failed to link transaction account: CH_975
# 	Failed to link transaction account: CH_403
# Link accountIdentifier IT_5013441 (30900/34210)
# 	Failed to link transaction account: GB_5017656
# Link accountIdentifier FI_5010830 (31000/34210)
# 	Failed to link transaction account: NZ_3528
# 	Failed to link transaction account: CH_1079
# 	Failed to link transaction account: NZ_1107
# 	Failed to link transaction account: CH_939
# 	Failed to link transaction account: JP_160
# 	Failed to link transaction account: CH_1060
# Link accountIdentifier ES_759 (31100/34210)
# 	Failed to link transaction account: CH_627
# Link accountIdentifier DE_2035 (31200/34210)
# 	Failed to link transaction account: CH_798
# 	Failed to link transaction account: CH_2056
# Link accountIdentifier DE_5015432 (31300/34210)
# 	Failed to link transaction account: CDM_2005
# 	Failed to link transaction account: JP_42
# Link accountIdentifier LT_22 (31400/34210)
# 	Failed to link transaction account: GB_5019248
# 	Failed to link transaction account: CH_917
# Link accountIdentifier FR_5005200 (31500/34210)
# 	Failed to link transaction account: RU_103
# 	Failed to link transaction account: GB_5016510
# 	Failed to link transaction account: NZ_10200
# 	Failed to link transaction account: CH_146
# Link accountIdentifier SE_5027087 (31600/34210)
# 	Failed to link transaction account: CH_501
# 	Failed to link transaction account: JP_63
# 	Failed to link transaction account: CH_1096
# 	Failed to link transaction account: CH_524
# 	Failed to link transaction account: JP_91
# Link accountIdentifier NL_553 (31700/34210)
# 	Failed to link transaction account: CH_676
# 	Failed to link transaction account: CH_669
# Link accountIdentifier IT_5013347 (31800/34210)
# 	Failed to link transaction account: CH_645
# Link accountIdentifier HU_5011707 (31900/34210)
# 	Failed to link transaction account: CH_406
# 	Failed to link transaction account: JP_118
# 	Failed to link transaction account: AU_1418
# Link accountIdentifier GB_5007767 (32000/34210)
# 	Failed to link transaction account: JP_370
# Link accountIdentifier BE_5026142 (32100/34210)
# 	Failed to link transaction account: GB_5020003
# Link accountIdentifier JP_14 (32200/34210)
# 	Failed to link transaction account: JP_14
# 	Failed to link transaction account: CH_130
# 	Failed to link transaction account: RU_102
# 	Failed to link transaction account: CDM_2198
# Link accountIdentifier FR_5019872 (32300/34210)
# 	Failed to link transaction account: CH_2115
# 	Failed to link transaction account: NZ_1917
# 	Failed to link transaction account: CH_783
# 	Failed to link transaction account: CH_809
# Link accountIdentifier DK_10 (32400/34210)
# 	Failed to link transaction account: GB_5018903
# 	Failed to link transaction account: NZ_2335
# 	Failed to link transaction account: GB_5018069
# Link accountIdentifier HU_5017414 (32500/34210)
# 	Failed to link transaction account: JP_307
# 	Failed to link transaction account: CH_637
# 	Failed to link transaction account: GB_5019137
# 	Failed to link transaction account: GB_5027635
# Link accountIdentifier SK_5022681 (32600/34210)
# 	Failed to link transaction account: CH_1000
# 	Failed to link transaction account: CDM_2140
# Link accountIdentifier GB_5017590 (32700/34210)
# 	Failed to link transaction account: EU_2312
# Link accountIdentifier SK_107 (32800/34210)
# 	Failed to link transaction account: CY0_12
# Link accountIdentifier FI_5010810 (32900/34210)
# 	Failed to link transaction account: CH_1073
# 	Failed to link transaction account: CH_122
# 	Failed to link transaction account: RU_105
# Link accountIdentifier SK_64 (33000/34210)
# 	Failed to link transaction account: CY0_16
# 	Failed to link transaction account: JP_73
# 	Failed to link transaction account: CH_683
# 	Failed to link transaction account: RU_42
# Link accountIdentifier NL_220 (33100/34210)
# 	Failed to link transaction account: JP_75
# 	Failed to link transaction account: CDM_2077
# 	Failed to link transaction account: CDM_2208
# Link accountIdentifier PT_166 (33200/34210)
# 	Failed to link transaction account: CH_643
# 	Failed to link transaction account: CH_580
# 	Failed to link transaction account: CH_531
# 	Failed to link transaction account: CH_107
# Link accountIdentifier IT_1701 (33300/34210)
# 	Failed to link transaction account: CH_2024
# 	Failed to link transaction account: GB_5017229
# 	Failed to link transaction account: NZ_4631
# Link accountIdentifier SK_5002963 (33400/34210)
# 	Failed to link transaction account: CH_818
# 	Failed to link transaction account: CH_549
# 	Failed to link transaction account: RU_117
# 	Failed to link transaction account: CH_772
# Link accountIdentifier CH_972 (33500/34210)
# 	Failed to link transaction account: CH_972
# 	Failed to link transaction account: GB_5017280
# 	Failed to link transaction account: CH_1114
# 	Failed to link transaction account: JP_471
# 	Failed to link transaction account: CH_694
# Link accountIdentifier DE_5015365 (33600/34210)
# 	Failed to link transaction account: NZ_5776
# 	Failed to link transaction account: CY0_3
# 	Failed to link transaction account: CDM_2118
# 	Failed to link transaction account: CDM_2165
# 	Failed to link transaction account: CH_179
# Link accountIdentifier FI_107 (33700/34210)
# Link accountIdentifier IT_5012939 (33800/34210)
# 	Failed to link transaction account: CH_703
# 	Failed to link transaction account: CDM_2093
# Link accountIdentifier RO_71 (33900/34210)
# Link accountIdentifier DK_14985 (34000/34210)
# 	Failed to link transaction account: AU_2231
# 	Failed to link transaction account: CH_511
# 	Failed to link transaction account: CH_993
# Link accountIdentifier DE_5015827 (34100/34210)
# 	Failed to link transaction account: CH_292
# 	Failed to link transaction account: CH_681
# 	Failed to link transaction account: CY0_20
# 	Failed to link transaction account: GB_5000100
# 	Failed to link transaction account: CDM_2004
# Link accountIdentifier ES_5009149 (34200/34210)
# 	Failed to link transaction account: JP_67
#       accountIdentifierDB  accountID
# 0              NL_5011583     101251
# 1                 FR_1021       8661
# 2              CZ_5006652      96320
# 3                 GB_2340      77218
# 4              GB_5007612      97280
# ...                   ...        ...
# 33408          GB_5007131      96799
# 33409             DE_2010       7457
# 33410             DK_3769      53024
# 33411          FR_5024727     113390
# 33412            DK_20870      89711
#
# [33413 rows x 2 columns]

# %%
# insert accountID into transaction data
for pf in ["acquiring", "transferring"]:
    df[pf + "AccountID"] = df[pf + "AccountIdentifierDB"].map(lambda x: res.get(x))

# %%
df.info(null_counts=10000000)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2079753 entries, 0 to 2079752
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   acquiringAccountIdentifier       2079663 non-null  float64
#  1   acquiringAccountName             2064667 non-null  object
#  2   acquiringAccountURL              2079604 non-null  object
#  3   acquiringRegistry                2079753 non-null  object
#  4   amount                           2079753 non-null  int64
#  5   expiryDate                       167 non-null      object
#  6   lulucfActivity                   357 non-null      float64
#  7   originalCommitmentPeriod         2079753 non-null  int64
#  8   originatingRegistry              2079753 non-null  object
#  9   projectID                        394960 non-null   float64
#  10  projectTrack                     60349 non-null    float64
#  11  transactionBlock                 2079753 non-null  int64
#  12  transactionDate                  2079753 non-null  object
#  13  transactionID                    2079753 non-null  object
#  14  transactionType                  2079753 non-null  object
#  15  transactionURL                   0 non-null        float64
#  16  transferringAccountIdentifier    2079515 non-null  float64
#  17  transferringAccountName          2040572 non-null  object
#  18  transferringAccountURL           2079584 non-null  object
#  19  transferringRegistry             2079753 non-null  object
#  20  unitType                         2079557 non-null  object
#  21  acquiringRegistryCode            2079753 non-null  object
#  22  transferringRegistryCode         2079753 non-null  object
#  23  acquiringAccountIdentifierDB     2079663 non-null  object
#  24  transferringAccountIdentifierDB  2079515 non-null  object
#  25  acquiringAccountID               2064844 non-null  float64
#  26  transferringAccountID            2040473 non-null  float64
# dtypes: float64(8), int64(3), object(16)
# memory usage: 428.4+ MB

# %%
df.to_csv(dir_in + "transactionBlocks.csv", index=False)
